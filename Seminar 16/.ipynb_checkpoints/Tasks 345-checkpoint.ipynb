# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, plot_roc_curve, accuracy_score, make_scorer, balanced_accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold, train_test_split, GridSearchCV
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Bonus19/BRCA_pam50.tsv", sep="\t", index_col=0)
df3 = df.loc[df["Subtype"].isin(["Luminal A","Luminal B"])]
X3 = df3.iloc[:, :-1].to_numpy()
y3 = df3["Subtype"].to_numpy()

# %% [markdown]
# ## Task 3

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(
    X3, y3, stratify=y3, test_size=0.2, random_state=17
)

# %%
svm = SVC(kernel="linear", C=3.5)
svm.fit(X3_train, y3_train); pass

# %%
y3_pred = svm.predict(X3_test)
print("Balanced accuracy score:", balanced_accuracy_score(y3_pred, y3_test))
M = confusion_matrix(y3_test, y3_pred)
print(M)
TPR = M[0, 0] / (M[0, 0] + M[0, 1])
TNR = M[1, 1] / (M[1, 0] + M[1, 1])
print("TPR:", round(TPR, 3), "TNR:", round(TNR, 3))

plot_roc_curve(svm, X3_test, y3_test)
plt.plot(1 - TPR, TNR, "x", c="red")
plt.show()
# Out:
# Balanced accuracy score: 0.8873949579831932
# [[78  5]
#  [ 7 30]]
# TPR: 0.94 TNR: 0.811

# %%
coef = np.argsort(np.abs(svm.coef_[0]))[-5:]
df3 = df3.iloc[:, coef]
X3 = df3.iloc[:, :-1].to_numpy()
X3_train, X3_test, y3_train, y3_test = train_test_split(
    X3, y3, stratify=y3, test_size=0.2, random_state=17
)

# %%
svm = SVC(kernel="linear", C=3.5)
svm.fit(X3_train, y3_train); pass

# %%
y3_pred = svm.predict(X3_test)
print("Balanced accuracy score:", balanced_accuracy_score(y3_pred, y3_test))
M = confusion_matrix(y3_test, y3_pred)
print(M)
TPR = M[0, 0] / (M[0, 0] + M[0, 1])
TNR = M[1, 1] / (M[1, 0] + M[1, 1])
print("TPR:", round(TPR, 3), "TNR:", round(TNR, 3))

plot_roc_curve(svm, X3_test, y3_test)
plt.plot(1 - TPR, TNR, "x", c="red")
plt.show()
# Out:
# Balanced accuracy score: 0.7395786642761093
# [[76  7]
#  [21 16]]
# TPR: 0.916 TNR: 0.432

# %% [markdown]
# ## Task 4

# %%
subtypes = set(y_test)
unique, counts = np.unique(y_test, return_counts=True)
test_counts = dict(zip(unique, counts))
unique, counts = np.unique(y_train, return_counts=True)
train_counts = dict(zip(unique, counts))

# %%
for subtype in subtypes:
    pred = 0
    for i in range(len(y_pred)):
        if y_test[i]==subtype==y_pred[i]:
            pred += 1
    test, train = test_counts[subtype], train_counts[subtype]
    print(subtype, f"(train: {train})")
    print("Accuracy score:", round(pred/test, 2), f"({pred}/{test})\n")
# Out:
# HER2-enriched (train: 51)
# Accuracy score: 0.69 (9/13)
#
# Normal-like (train: 18)
# Accuracy score: 0.0 (0/4)
#
# Luminal A (train: 329)
# Accuracy score: 0.91 (75/82)
#
# Luminal B (train: 148)
# Accuracy score: 0.68 (25/37)
#
# Healthy (train: 79)
# Accuracy score: 0.95 (19/20)
#
# Triple-negative (train: 107)
# Accuracy score: 1.0 (27/27)

# %% [markdown]
# ## Task 3

# %%
model = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", NearestCentroid())
])
model.fit(X_train, y_train); pass

# %%
y_pred = model.predict(X_test)
print("Accuracy score:", round(accuracy_score(y_pred, y_test), 3))
# Out:
# Accuracy score: 0.863

# %%
subtypes = set(y_test)
unique, counts = np.unique(y_test, return_counts=True)
test_counts = dict(zip(unique, counts))
unique, counts = np.unique(y_train, return_counts=True)
train_counts = dict(zip(unique, counts))

# %%
for subtype in subtypes:
    pred = 0
    for i in range(len(y_pred)):
        if y_test[i]==subtype==y_pred[i]:
            pred += 1
    test, train = test_counts[subtype], train_counts[subtype]
    print(subtype, f"(train: {train})")
    print("Accuracy score:", round(pred/test, 2), f"({pred}/{test})\n")
# Out:
# HER2-enriched (train: 51)
# Accuracy score: 1.0 (13/13)
#
# Normal-like (train: 18)
# Accuracy score: 0.5 (2/4)
#
# Luminal A (train: 329)
# Accuracy score: 0.82 (67/82)
#
# Luminal B (train: 148)
# Accuracy score: 0.84 (31/37)
#
# Healthy (train: 79)
# Accuracy score: 0.9 (18/20)
#
# Triple-negative (train: 107)
# Accuracy score: 1.0 (27/27)

# %% [markdown]
# ## Task 4

# %%
def metrics(dot1, dot2):
    x1, x2 = dot1
    y1, y2 = dot2
    eucl = ((x1-y1)**2 + (x2-y2)**2) ** 0.5
    manh = abs(x1-y1) + abs(x2-y2)
    print("Euclidean metrics:", round(eucl, 2))
    print("Manhattan metrics:", round(manh, 2))
    return eucl, manh

def closer(m1, m2):
    if m1 < m2:
        m_res = "class 1"
    elif m1 > m2:
        m_res = "class 2"
    else:
        m_res = "equal"
    return m_res

# %%
class1 = [5,6]
class2 = [10,0]
dot = [0,0]

print("Distance to class 1")
eucl_1, manh_1 = metrics(dot, class1)
print("\nDistance to class 2")
eucl_2, manh_2 = metrics(dot, class2)

print("\nIn euclidean metric is closer:", closer(eucl_1, eucl_2))
print("In manhattan metric is closer:", closer(manh_1, manh_2))
# Out:
# Distance to class 1
# Euclidean metrics: 7.81
# Manhattan metrics: 11
#
# Distance to class 2
# Euclidean metrics: 10.0
# Manhattan metrics: 10
#
# In euclidean metric is closer: class 1
# In manhattan metric is closer: class 2

# %%
Image(filename='Task4.jpg', width=620 , height=420)

# %% [markdown]
# ## Task 5
